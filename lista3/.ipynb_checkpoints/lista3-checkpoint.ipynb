# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Zadanie 0

# %% [markdown]
# ### 1. Load IRIS dataset

# %%
# Load Iris
iris_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_df = pd.read_csv(
    iris_url, header=None, 
    names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'])

# %% [markdown]
# ### 2. Kmeans and other functions

# %%
def calc_dists(A,B):
    return np.square(np.sum(np.square(A)[:,np.newaxis,:], axis=2) - 2 * A.dot(B.T) + np.sum(np.square(B), axis=1))

def plot(data_df, centroids_df, x_name, y_name):  
    for index, centroid in centroids_df.iterrows():
        plt.scatter(centroid[x_name], centroid[y_name], marker='x', color='black')
    for id_centroid in data_df['closest_centroid'].unique().tolist():
        group = data_df[data_df['closest_centroid'] == id_centroid]
        plt.scatter(group[x_name], group[y_name], marker='.' )
        plt.title('K: ' + str(len(centroids_df)))
    plt.show()

    
def funn(data):
    return (data - data.mean())**2
    
def W(data):
    a = (data - data.mean()).values
    return np.sum(np.diag(np.dot(a,a.T)))

def BIC(data):
    return -2 * wdc(data) + data['closest_centroid'].nunique() * np.log(len(data))

def B(data, mean):
    a = data.mean().values - mean
    return len(data) * np.dot(a,a.T)


def kmeans(data_df, K, measure_fun):

    centroids = data_df.sample(K)
    data_df['closest_centroid'] = -1

    for i in range(100):
        data_df.drop(columns = ['closest_centroid'], inplace=True)
        dists = calc_dists(data_df.values,centroids.values)
        data_df['closest_centroid'] = dists.argmin(axis=1)
        centroids = data_df.groupby(['closest_centroid']).mean()
    
    measure = -1
    if measure_fun == 'W':
        measure=np.sum(np.sum(data_df.groupby(['closest_centroid']).apply(W)))
    elif measure_fun == 'B':
        global_mean = data_df.mean().values
        measure=np.sum(np.sum(data_df.groupby(['closest_centroid']).apply(B,global_mean)))
    elif measure_fun == 'BIC':
        measure=np.sum(np.sum(data_df.groupby(['closest_centroid']).apply(BIC)))
   
    return data_df, measure

# %% [markdown]
# ### 3. Plot few different measures

# %%
data = iris_df.drop(['target'], axis=1)

res = []
kk = []
bic = []
w = []
b = []
n_k = 7
for k in range(1,n_k):
    bic.append(-kmeans(data.copy(),k,'BIC')[0])
    w.append(kmeans(data.copy(),k,'W')[0])
    b.append(-kmeans(data.copy(),k,'B')[0])
    kk.append(k)

plt.xticks(np.arange(1,n_k))
plt.xlabel('k')
plt.legend(['-BIC','tr(W)','-tr(B)'])
plt.plot(kk, bic, 'bo', linestyle = 'dashed')
plt.plot(kk, w, 'go', linestyle = 'dashed')
plt.plot(kk, b, 'ro', linestyle = 'dashed')
plt.show()

# %% [markdown]
# #### 4. Plot grouped data

# %%
#sns.pairplot(data, hue="target")
data_tmp = data
kmeans(data_tmp,2,'W')
data_tmp['closest_centroid'] = "kat_" + data_tmp['closest_centroid'].astype(str)

sns.pairplot(data_tmp, hue='closest_centroid')

# %% [markdown]
# # Zadanie 1

# %% [markdown]
# ### a)

# %%
N = 5000
d = 2
K = 5

p = np.repeat(1/K,K)
k = np.arange(1,K+1,1)
mu = np.repeat([3*k],d).reshape(K,d)

covariance_matrix = np.eye(d)

data = []
for i in range(N):
    x = np.random.multivariate_normal(mu[np.random.choice(np.arange(K), p=p)],covariance_matrix,1)
    data.append(x)
data = np.vstack(data)

data_df = pd.DataFrame(data=data, index=np.arange(1,N+1,1), columns=['x','y'])  # 1st row as the column names

res = []
kk = []
bic = []
w = []
b = []
n_k = 10
for k in range(1,n_k):
    bic.append(-kmeans(data_df.copy(),k,'BIC')[1])
    w.append(kmeans(data_df.copy(),k,'W')[1])
    b.append(-kmeans(data_df.copy(),k,'B')[1])
    kk.append(k)

plt.xticks(np.arange(1,n_k))
plt.xlabel('k')
plt.legend(['-BIC','tr(W)','-tr(B)'])
plt.plot(kk, bic, 'bo', linestyle = 'dashed')
plt.plot(kk, w, 'go', linestyle = 'dashed')
plt.plot(kk, b, 'ro', linestyle = 'dashed')
plt.show()

sns.lmplot('x', 'y', markers = '.', data=kmeans(data_df.copy(),5,'W')[0], hue='closest_centroid', fit_reg=False)

# %% [markdown]
# ### b)

# %%
N = 5000
d = 2
K = 5

p = np.repeat(1/K,K)
k = np.arange(1,K+1,1)
mu = np.repeat([3*k],d).reshape(K,d)


sigma1 = np.eye(d)
sigma3 = np.array([[3,0],[0,1]])

covariance_matrix = np.concatenate((sigma1,sigma1,sigma3,sigma1,sigma1)).reshape(K,d,d)


data = []
for i in range(N):
    ran = np.random.choice(np.arange(K), p=p)
    x = np.random.multivariate_normal(mu[np.random.choice(np.arange(K), p=p)],covariance_matrix[ran],1)
    data.append(x)
data = np.vstack(data)

data_df = pd.DataFrame(data=data, index=np.arange(1,N+1,1), columns=['x','y'])  # 1st row as the column names

res = []
kk = []
bic = []
w = []
b = []
n_k = 10
for k in range(1,n_k):
    bic.append(-kmeans(data_df.copy(),k,'BIC')[1])
    w.append(kmeans(data_df.copy(),k,'W')[1])
    b.append(-kmeans(data_df.copy(),k,'B')[1])
    kk.append(k)

plt.xticks(np.arange(1,n_k))
plt.xlabel('k')
plt.legend(['-BIC','tr(W)','-tr(B)'])
plt.plot(kk, bic, 'bo', linestyle = 'dashed')
plt.plot(kk, w, 'go', linestyle = 'dashed')
plt.plot(kk, b, 'ro', linestyle = 'dashed')
plt.show()

sns.lmplot('x', 'y', markers = '.', data=kmeans(data_df.copy(),5,'W')[0], hue='closest_centroid', fit_reg=False)

# %% [markdown]
# ### c)

# %%
N = 5000
d = 2
K = 5

p = np.repeat(1/K,K)
k = np.arange(1,K+1,1)
mu = np.repeat([3*k],d).reshape(K,d)


sigma1 = np.eye(d)
sigma3 = np.array([[3,1],[1,1]])

covariance_matrix = np.concatenate((sigma1,sigma1,sigma3,sigma1,sigma1)).reshape(K,d,d)

data = []
for i in range(N):
    ran = np.random.choice(np.arange(K), p=p)
    x = np.random.multivariate_normal(mu[np.random.choice(np.arange(K), p=p)],covariance_matrix[ran],1)
    data.append(x)
data = np.vstack(data)

data_df = pd.DataFrame(data=data, index=np.arange(1,N+1,1), columns=['x','y'])  # 1st row as the column names

res = []
kk = []
bic = []
w = []
b = []
n_k = 10
for k in range(1,n_k):
    bic.append(-kmeans(data_df.copy(),k,'BIC')[1])
    w.append(kmeans(data_df.copy(),k,'W')[1])
    b.append(-kmeans(data_df.copy(),k,'B')[1])
    kk.append(k)

plt.xticks(np.arange(1,n_k))
plt.xlabel('k')
plt.legend(['-BIC','tr(W)','-tr(B)'])
plt.plot(kk, bic, 'bo', linestyle = 'dashed')
plt.plot(kk, w, 'go', linestyle = 'dashed')
plt.plot(kk, b, 'ro', linestyle = 'dashed')
plt.show()

sns.lmplot('x', 'y', markers = '.', data=kmeans(data_df.copy(),5,'W')[0], hue='closest_centroid', fit_reg=False)

# %% [markdown]
# ### d)

# %%
N = 5000
d = 2
K = 5

p = np.array([.2,.1,.3,.1,.3])
k = np.arange(1,K+1,1)
mu = np.repeat([3*k],d).reshape(K,d)


sigma1 = np.eye(d)
sigma3 = np.array([[3,0],[0,1]])

covariance_matrix = np.concatenate((sigma1,sigma1,sigma3,sigma1,sigma1)).reshape(K,d,d)

data = []
for i in range(N):
    ran = np.random.choice(np.arange(K), p=p)
    x = np.random.multivariate_normal(mu[np.random.choice(np.arange(K), p=p)],covariance_matrix[ran],1)
    data.append(x)
data = np.vstack(data)

data_df = pd.DataFrame(data=data, index=np.arange(1,N+1,1), columns=['x','y'])  # 1st row as the column names

res = []
kk = []
bic = []
w = []
b = []
n_k = 10
for k in range(1,n_k):
    bic.append(-kmeans(data_df.copy(),k,'BIC')[1])
    w.append(kmeans(data_df.copy(),k,'W')[1])
    b.append(-kmeans(data_df.copy(),k,'B')[1])
    kk.append(k)

plt.xticks(np.arange(1,n_k))
plt.xlabel('k')
plt.legend(['-BIC','tr(W)','-tr(B)'])
plt.plot(kk, bic, 'bo', linestyle = 'dashed')
plt.plot(kk, w, 'go', linestyle = 'dashed')
plt.plot(kk, b, 'ro', linestyle = 'dashed')
plt.show()

sns.lmplot('x', 'y', markers = '.', data=kmeans(data_df.copy(),5,'W')[0], hue='closest_centroid', fit_reg=False)

# %% [markdown]
# ### e)

# %%
N = 5000
d = 3
K = 5

p = np.repeat(1/K,K)
k = np.arange(1,K+1,1)
mu = np.repeat([3*k],d).reshape(K,d)


sigma1 = np.eye(d)
sigma3 = np.array([[3,1,0],[1,1,0],[0,0,1]])


covariance_matrix = np.concatenate((sigma1,sigma1,sigma3,sigma1,sigma1)).reshape(K,d,d)

data = []
for i in range(N):
    ran = np.random.choice(np.arange(K), p=p)
    x = np.random.multivariate_normal(mu[np.random.choice(np.arange(K), p=p)],covariance_matrix[ran],1)
    data.append(x)
data = np.vstack(data)

data_df = pd.DataFrame(data=data, index=np.arange(1,N+1,1), columns=['x','y', 'z'])  # 1st row as the column names

res = []
kk = []
bic = []
w = []
b = []
n_k = 10
for k in range(1,n_k):
    bic.append(-kmeans(data_df.copy(),k,'BIC')[1])
    w.append(kmeans(data_df.copy(),k,'W')[1])
    b.append(-kmeans(data_df.copy(),k,'B')[1])
    kk.append(k)

plt.xticks(np.arange(1,n_k))
plt.xlabel('k')
plt.legend(['-BIC','tr(W)','-tr(B)'])
plt.plot(kk, bic, 'bo', linestyle = 'dashed')
plt.plot(kk, w, 'go', linestyle = 'dashed')
plt.plot(kk, b, 'ro', linestyle = 'dashed')
plt.show()

sns.lmplot('x', 'y', markers = '.', data=kmeans(data_df.copy(),5,'W')[0], hue='closest_centroid', fit_reg=False)

sns.lmplot('y', 'z', markers = '.', data=kmeans(data_df.copy(),5,'W')[0], hue='closest_centroid', fit_reg=False)

sns.lmplot('x', 'z', markers = '.', data=kmeans(data_df.copy(),5,'W')[0], hue='closest_centroid', fit_reg=False)

# %%
# from mpl_toolkits import mplot3d

# ax = plt.axes(projection='3d')


# # Data for three-dimensional scattered points
# zdata = data[:,0]
# xdata = data[:,1]
# ydata = data[:,2]
# ax.scatter3D(xdata, ydata, zdata);
# xdata

# %% [markdown]
# ### f)

# %%
N = 5000
d = 100
K = 10

p = np.repeat(1/K,K)
k = np.arange(1,K+1,1)
mu = np.repeat([3*k],d).reshape(K,d)


Covariance = np.eye(d)


data = []
for i in range(N):
    ran = np.random.choice(np.arange(K), p=p)
    x = np.random.multivariate_normal(mu[ran],Covariance,1)
    data.append(x)
data = np.vstack(data)

data_df = pd.DataFrame(data=data, index=np.arange(1,N+1,1), columns=list(map(str,np.arange(1,d+1,1))) )  # 1st row as the column names

distortion = []
k_list = []
for k in range(1,20):
    distortion.append(kmeans(data_df.copy(),k,False))
    k_list.append(k)
plt.plot(k_list, distortion, 'bo', linestyle = 'dashed')
plt.xlabel('k')
plt.ylabel('distortion')
plt.show()

# %%
# Out:
# ['1', '2', '3', '4', '5']

# %%
def plot_clouds(K,d,N):

    alfa = 2*np.pi/K
    rotation_matrix = np.array([[np.cos(alfa),np.sin(alfa)],[-np.sin(alfa),np.cos(alfa)]])

    centres = np.zeros(2*K).reshape(K,2)
    points = np.empty([1,2])
    
    R = d/(2*np.sin(np.pi/K))


    for i in range(K):
        point = np.dot(np.linalg.matrix_power(rotation_matrix,i), np.array([0,R]))
        centres[i,0] = point[0]
        centres[i,1] = point[1]
        x = np.random.normal(point[0],1,N)
        y = np.random.normal(point[1],1,N)
        points = np.concatenate((points,np.array([x,y]).T),axis=0)
        plt.plot(x,y,'.')
    
    points = points[ np.arange(1,N*K+1) ]
    
    plt.plot(centres[:,0], centres[:,1], color='black')
    plt.plot(np.array([centres[0,0], centres[K-1,0]]), np.array([centres[0,1], centres[K-1,1]]), color='black')
    plt.axis('square')
    return points

# %%
N = 10000
d = 100
K = 1000
q=10

p = np.repeat(1/K,K)
k = np.arange(1,K+1,1)
mu = np.repeat([q*k],d).reshape(K,d)

Covariance = np.eye(d)

data = []
for i in range(N):
    ran = np.random.choice(np.arange(K), p=p)
    x = np.random.multivariate_normal(mu[ran],Covariance,1)
    data.append(x)
data = np.vstack(data)

data_df = pd.DataFrame(data=data, index=np.arange(1,N+1,1), columns=list(map(str,np.arange(1,d+1,1))) )  # 1st row as the column names

# %%
kmeans(data_df.copy(),K,False)
# Out:
# 13413907.443884332

# %% [markdown]
# # Zadanie 3

# %%
#@title Data Loading
# We will load a few commonly used datasets:
# - iris
# - wine

# 1. Iris
iris_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_df = pd.read_csv(
    iris_url, header=None, 
    names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'])

# 2. Wine
wine_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
wine_df = pd.read_csv(
    wine_url, header=None, 
    names=['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanhoycanina', 'color_intensity', 'hue', 'diluted_wines', 'proline'])

# 2. Haberman
haberman_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/haberman/haberman.data'
haberman_df = pd.read_csv(
    haberman_url, header=None, 
    names=['age','year', 'axillary_nodes', 'target'])

haberman_df.head()
# Out:
#    age  year  axillary_nodes  target
# 0   30    64               1       1
# 1   30    62               3       1
# 2   30    65               0       1
# 3   31    59               2       1
# 4   31    65               4       1

# %%
sns.pairplot(iris_df, hue="target")

# %%
kmeans(iris_df.iloc[:,0:4],1)
# Out:
# 680.8243999999996

# %%
#sns.pairplot(haberman_df, hue="target")

haberman_df['target'] = haberman_df['target'].astype(str)


sns.pairplot(haberman_df,hue="target", diag_kind='hist')

# %%
from mpl_toolkits import mplot3d

ax = plt.axes(projection='3d')



zdata = np.array([30,30])
xdata = np.array([62,65])
ydata = np.array([3,0])
print(zdata,xdata,ydata)
ax.scatter(xdata, ydata, zdata);

# Data for three-dimensional scattered points
zdata = haberman_df.values[1:3,0]
xdata = haberman_df.values[1:3,1]
ydata = haberman_df.values[1:3,2]
ax.scatter(xdata, ydata, zdata);
print(zdata,xdata,ydata)
# Out:
# [30 30] [62 65] [3 0]
# [30 30] [62 65] [3 0]
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fe0f2f91378> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/PycharmProjects/ML/venv/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/PycharmProjects/ML/venv/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ...

# %%
#haberman_df.iloc[:,3].replace(1,'df')
#kmeans(haberman_df.iloc[:,0:3],3,'W')

data = haberman_df.drop(['target'], axis=1)

res = []
kk = []
bic = []
w = []
b = []
for k in range(1,6):
    bic.append(-kmeans(data.copy(),k,'BIC'))
    w.append(kmeans(data.copy(),k,'W'))
    b.append(-kmeans(data.copy(),k,'B'))
    kk.append(k)

plt.plot(kk, bic, 'bo', linestyle = 'dashed')
plt.plot(kk, w, 'go', linestyle = 'dashed')
plt.plot(kk, b, 'ro', linestyle = 'dashed')
plt.legend(['-BIC','tr(W)','-tr(B)'])

# %%
K=3


def calc_dists(A,B):
    return np.square(np.sum(np.square(A)[:,np.newaxis,:], axis=2) - 2 * A.dot(B.T) + np.sum(np.square(B), axis=1))

def plot(data_df, centroids_df, x_name, y_name):  
    for index, centroid in centroids_df.iterrows():
        plt.scatter(centroid[x_name], centroid[y_name], marker='x', color='black')
    for id_centroid in data_df['closest_centroid'].unique().tolist():
        group = data_df[data_df['closest_centroid'] == id_centroid]
        plt.scatter(group[x_name], group[y_name], marker='.' )
        plt.title('K: ' + str(len(centroids_df)))
    plt.show()

    
def funn(data):
    return (data - data.mean())**2
    
def W(data):
    a = (data - data.mean()).values
    return np.sum(np.diag(np.dot(a,a.T)))

def BIC(data):
    return -2 * wdc(data) + data['closest_centroid'].nunique() * np.log(len(data))

def B(data, mean):
    a = data.mean().values - mean
    return len(data) * np.dot(a,a.T)


def kmeans(data_df, K, measure_fun):

    centroids = data_df.sample(K)
    data_df['closest_centroid'] = -1

    for i in range(100):
        data_df.drop(columns = ['closest_centroid'], inplace=True)
        dists = calc_dists(data_df.values,centroids.values)
        data_df['closest_centroid'] = dists.argmin(axis=1)
        centroids = data_df.groupby(['closest_centroid']).mean()
    
    measure = -1
    if measure_fun == 'W':
        measure=np.sum(np.sum(data_df.groupby(['closest_centroid']).apply(W)))
    elif measure_fun == 'B':
        global_mean = data.mean().values
        measure=np.sum(np.sum(data_df.groupby(['closest_centroid']).apply(B,global_mean)))
    elif measure_fun == 'BIC':
        measure=np.sum(np.sum(data_df.groupby(['closest_centroid']).apply(BIC)))
   
        
    return centroids

# %% [markdown]
# # Lena

# %%
lena_array = plt.imread('/home/michal/Pulpit/ania.png')

lena_df = lena_array.reshape(np.shape(lena_array)[0]*np.shape(lena_array)[1], np.shape(lena_array)[2])

N = len(lena_df)
image_df = pd.DataFrame(data=lena_df, index=np.arange(1,N+1,1), columns=['r','g','b'])  # 1st row as the column names

centres = kmeans(image_df,4, 'W')
image_df.head()
# Out:
#           r         g         b  closest_centroid
# 1  0.815686  0.815686  0.815686                 0
# 2  0.823529  0.823529  0.823529                 0
# 3  0.827451  0.827451  0.827451                 0
# 4  0.831373  0.831373  0.831373                 0
# 5  0.831373  0.831373  0.831373                 0

# %%
lena_array[:,1]
# Out:
# array([[0.8862745 , 0.5372549 , 0.49019608],
#        [0.8862745 , 0.5372549 , 0.49019608],
#        [0.8862745 , 0.5372549 , 0.49019608],
#        ...,
#        [0.32941177, 0.07058824, 0.23529412],
#        [0.32156864, 0.08627451, 0.22352941],
#        [0.32156864, 0.08627451, 0.22352941]], dtype=float32)

# %%
for k in range(1,20):
    image_df = pd.DataFrame(data=lena_df, index=np.arange(1,N+1,1), columns=['r','g','b'])  # 1st row as the column names
    centres = kmeans(image_df,k, 'W')
    image_df.head()

    a = image_df.join(centres,'closest_centroid',lsuffix='_')[['r','g','b']].values


    plt.imshow(a.reshape(128,128,3))
    plt.savefig("/home/michal/Pulpit/" +"ania_" + str(k) + ".png")
    #plt.imshow(lena_array)
